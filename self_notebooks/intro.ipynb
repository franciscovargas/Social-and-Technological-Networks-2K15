# %%
import networkx as nx
import matplotlib.pylab as plt
# %matplotlib inline

# %%
g = nx.Graph()

# %%
g.add_edge(1,2)
g.add_edge(2,3)
g.add_edge(1,3)
g.add_edge(1,4)
g.add_edge(4,6)
g.add_node(7)

# %%
nx.draw(g)

# %%
kc = nx.karate_club_graph()

# %%
nx.draw(kc)

# %%
g = nx.erdos_renyi_graph(50, 0.1)
nx.draw(g)

# %%
nx.diameter(g)
# Out:
# 4

# %%
ws = nx.watts_strogatz_graph(50, 3, 0.1) #small world graph

nx.draw(ws)

# %%
nx.diameter(ws)
# Out:
# 27
